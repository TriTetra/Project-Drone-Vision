# %% [markdown]
# # Drawing Shapes and Text on Images
#
# This notebook demonstrates how to draw basic geometric shapes and text on an image canvas using OpenCV. These functions are essential for annotating images, visualizing results (like bounding boxes), or creating simple user interfaces.

# %% [markdown]
# ### Table of Contents
#
# - [Step 1: Setup](#Step-1:-Setup)
# - [Step 2: Create a Blank Canvas](#Step-2:-Create-a-Blank-Canvas)
# - [Step 3: Drawing Shapes](#Step-3:-Drawing-Shapes)
# - [Step 4: Adding Text](#Step-4:-Adding-Text)
# - [Step 5: Display the Final Image](#Step-5:-Display-the-Final-Image)

# %% [markdown]
# ### Step 1: Setup
#
# First, we import the necessary libraries. We only need to do this once at the beginning of our script.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Set default figure size for matplotlib plots
plt.rcParams['figure.figsize'] = (10, 8)

# %% [markdown]
# ### Step 2: Create a Blank Canvas
#
# Instead of loading an image, we can create a blank black canvas to draw on. We use `np.zeros` to create a 3-channel (BGR) image of size 512x512, with an 8-bit unsigned integer data type (`uint8`).

# %%
canvas = np.zeros((512, 512, 3), dtype="uint8")
# To make it a white canvas, we can add 255 to all pixels
canvas[:] = (255, 255, 255)

# %%
plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %% [markdown]
# ### Step 3: Drawing Shapes
#
# Now we will draw various shapes onto our canvas. Note how each function takes the canvas as the first argument, followed by coordinates, color (BGR), and thickness.

# %%
# Draw a green line
cv2.line(canvas, (0, 0), (511, 511), (0, 255, 0), 5)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %%
# Draw a red outlined rectangle
cv2.rectangle(canvas, (100, 100), (300, 250), (0, 0, 255), 5)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %%
# Draw a blue, filled rectangle
cv2.rectangle(canvas, (400, 50), (500, 150), (255, 0, 0), -1)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %%
# Draw a cyan, filled circle
center_x, center_y = (canvas.shape[1] // 2, canvas.shape[0] // 2)
cv2.circle(canvas, (center_x, center_y), 50, (255, 255, 0), -1)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %%
# Draw a triangle using cv2.polylines
triangle_pts = np.array([[300, 100], [250, 150], [350, 150]], np.int32)
pts = triangle_pts.reshape((-1, 1, 2))
cv2.polylines(canvas, [pts], True, (0, 0, 0), 3)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %% [markdown]
# ### Step 4: Adding Text
#
# You can write text on an image using `cv2.putText()`. This function gives you control over the font, size, color, and line type.

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(canvas, "OpenCV Drawing", (10, 40), font, 1.2, (0, 0, 0), 2, cv2.LINE_AA)

plt.figure(figsize=(6,6))
plt.imshow(canvas)
plt.show()

# %% [markdown]
# ### Step 5: Display the Final Image
#
# Now we display the canvas with all the shapes and text we've drawn using Matplotlib for better inline visualization.

# %%
# Convert BGR image to RGB for Matplotlib display
canvas_rgb = cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(canvas_rgb)
plt.title("Canvas with Shapes and Text")
plt.axis('off')
plt.show()
